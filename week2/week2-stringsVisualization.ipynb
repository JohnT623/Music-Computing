# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnT623/Music-Computing/blob/main/week2/week2-stringsVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generate a time series

# %%
import numpy as np
radians = np.arange(0, 2*np.pi, 0.01);

# %% [markdown]
# # Plot the time series using the matplotlib library

# %%
import matplotlib.pylab as plt
# plot the time series against the same time series
# https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.plot.html
# plt.plot(xvals, yvals)
plt.plot(radians, radians)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.axis('tight')
plt.show()

# %% [markdown]
# # Plot the time series against the sine of the time series

# %%
plt.plot(radians, np.sin(radians))
plt.xlabel('Radians')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# # Create strings for the x and y axis labels

# %%
xlabel = 'Radians'
ylabel = 'Amplitude'

# %% [markdown]
# # Plot using the label strings

# %%
plt.plot(radians, np.sin(radians))
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b54a38b5b46d> in <cell line: 0>()
#       1 plt.plot(radians, np.sin(radians))
# ----> 2 plt.xlabel(xlabel)
#       3 plt.ylabel(ylabel)
#       4 plt.show()
#
# NameError: name 'xlabel' is not defined

# %% [markdown]
# # Plot the sine wave with degrees in the x-axis instead of time

# %%
# use the numpy function rad2deg to convert
plt.plot(np.rad2deg(radians), np.sin(radians))
plt.xlabel('Degrees')
plt.ylabel(ylabel)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-00f758dcee2a> in <cell line: 0>()
#       2 plt.plot(np.rad2deg(radians), np.sin(radians))
#       3 plt.xlabel('Degrees')
# ----> 4 plt.ylabel(ylabel)
#       5 plt.show()
#
# NameError: name 'ylabel' is not defined

# %% [markdown]
# # Import an audio file from class GitHub repo using librosa library

# %%
# !git clone https://github.com/jcdevaney/imc2023.git

import librosa
import librosa.display
file = 'imc2023/audioFiles/avm.wav'
sig , sr = librosa.load(file,mono=True,sr=None)
# Out:
# Cloning into 'imc2023'...
# remote: Enumerating objects: 130, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 130 (delta 28), reused 18 (delta 18), pack-reused 96 (from 1)
# Receiving objects: 100% (130/130), 16.27 MiB | 24.68 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %% [markdown]
# # Calculate the length in seconds

# %%
length_s = sig.shape[0] / sr
print(length_s)
# Out:
# 12.466802721088435

# %% [markdown]
# # Plot the time-domain representation of avm.wav

# %%
plt.plot(sig)

# %% [markdown]
# # Plot with time on the x-axis

# %%
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

# %% [markdown]
# # Plot with amplitude on the y-axis

# %%
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %% [markdown]
# # Plot with labels

# %%
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel(ylabel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-e91cf7044257> in <cell line: 0>()
#       2 plt.plot(time,sigNew)
#       3 plt.xlabel('Time (seconds)')
# ----> 4 plt.ylabel(ylabel)
#
# NameError: name 'ylabel' is not defined
